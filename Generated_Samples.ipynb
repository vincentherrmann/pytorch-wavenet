# %% [markdown]
# Here are audio clips generated by a model that was trained on the Chaconne from the Partita in D minor for Violin by Johann Sebastian Bach.
#
# ### temperature 1.0:

# %%
import IPython
IPython.display.Audio("generated_samples/chaconne_temp_1,0.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### temperature 0.8:

# %%
IPython.display.Audio("generated_samples/chaconne_temp_0,8.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### temperature 0.5:

# %%
IPython.display.Audio("generated_samples/chaconne_temp_0,5.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
