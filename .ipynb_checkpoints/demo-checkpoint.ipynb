# %%
import time

from model import Model, Optimizer, WavenetData

from IPython.display import Audio
from IPython.core.debugger import Tracer
from matplotlib import pyplot as plt
from matplotlib import pylab as pl
from IPython import display
import torch
import numpy as np
#%matplotlib inline
# %matplotlib notebook

# %%
model = Model(num_time_samples=10000, 
              num_blocks=2, 
              num_layers=11, 
              num_hidden=128, 
              num_classes=256)
print('model: ', model)
print('scope: ', model.scope)
# Out:
# current scope:  1
# current scope:  3
# current scope:  7
# current scope:  15
# current scope:  31
# current scope:  63
# current scope:  127
# current scope:  255
# current scope:  511
# current scope:  1023
# current scope:  2047
# current scope:  2048
# current scope:  2050
# current scope:  2054
# current scope:  2062
# current scope:  2078
# current scope:  2110
# current scope:  2174
# current scope:  2302
# current scope:  2558
# current scope:  3070
# current scope:  4094
# scope:  6142
# model:  Model (
#   (main): Sequential (
#     (b0-l0.conv_dilation1): ConvDilated (
#       (conv): Conv1d(1, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b0-l1.conv_dilation2): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b0-l2.conv_dilation4): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b0-l3.conv_dilation8): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b0-l4.conv_dilation16): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b0-l5.conv_dilation32): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b0-l6.conv_dilation64): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b0-l7.conv_dilation128): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b0-l8.conv_dilation256): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b0-l9.conv_dilation512): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b0-l10.conv_dilation1024): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l0.conv_dilation1): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l1.conv_dilation2): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l2.conv_dilation4): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l3.conv_dilation8): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l4.conv_dilation16): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l5.conv_dilation32): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l6.conv_dilation64): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l7.conv_dilation128): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l8.conv_dilation256): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l9.conv_dilation512): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (b1-l10.conv_dilation1024): ConvDilated (
#       (conv): Conv1d(128, 128, kernel_size=(2,), stride=(1,), bias=False)
#     )
#     (final): Final (
#       (conv): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#     )
#   )
# )
# scope:  6142

# %%
data = WavenetData('saber.wav',
                   input_length=model.scope,
                   target_length=model.last_block_scope,
                   num_classes=model.num_classes)
start_tensor = data.get_minibatch([30000])[0].squeeze()
plt.ion()
plt.plot(start_tensor[-200:].numpy())
plt.ioff()
# Out:
# <img src="data:image/png;base64,...">

# %%
optimizer = Optimizer(model,
                      learning_rate=0.003,
                      stop_threshold=0.1,
                      avg_length=4)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

def hook(losses):
    ax.clear()
    ax.plot(losses)
    fig.canvas.draw()
    #print(losses[-1])
    
optimizer.hook = hook

#Tracer()()

print('start training...')
tic = time.time()
optimizer.train(data)
toc = time.time()
print('Training took {} seconds.'.format(toc-tic))
# Out:
# <img src="data:image/png;base64,...">
# start training...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-cbc8f10fcfd4> in <module>()
#      18 print('start training...')
#      19 tic = time.time()
# ---> 20 optimizer.train(data)
#      21 toc = time.time()
#      22 print('Training took {} seconds.'.format(toc-tic))
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/model.py in train(self, data)
#     223                         inputs, targets = data.get_minibatch([index])
#     224
# --> 225                         output = self.model(Variable(inputs))
#     226
#     227                         #print('step...')
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/model.py in forward(self, input)
#      72
#      73         def forward(self, input):
# ---> 74                 x = self.main(input)
#      75                 return x
#      76
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/container.py in forward(self, input)
#      62     def forward(self, input):
#      63         for module in self._modules.values():
# ---> 64             input = module(input)
#      65         return input
#      66
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/wavenet_modules.py in forward(self, x)
#      52                         x = constant_pad_1d(x, self.kernel_size-l, dimension=2, pad_start=True)
#      53
# ---> 54                 r = self.conv(x)
#      55
#      56                 if self.residual:
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     141     def forward(self, input):
#     142         return F.conv1d(input, self.weight, self.bias, self.stride,
# --> 143                         self.padding, self.dilation, self.groups)
#     144
#     145
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/functional.py in conv1d(input, weight, bias, stride, padding, dilation, groups)
#      60     f = ConvNd(_single(stride), _single(padding), _single(dilation), False,
#      61                _single(0), groups, torch.backends.cudnn.benchmark, torch.backends.cudnn.enabled)
# ---> 62     return f(input, weight, bias)
#      63
#      64
#
# KeyboardInterrupt:

# %%
#torch.save(model, 'trained_model')

#start_tensor = torch.zeros((model.scope)) + 0
start_tensor = data.get_minibatch([12345])[0].squeeze()
print('generate...')
tic = time.time()
generated = model.generate(start_data=start_tensor, num_generate=200)
#generated = model.fast_generate(40000, first_sample=0.1)
toc = time.time()
print('Generating took {} seconds.'.format(toc-tic))
# Out:
# generate...
# pad zero
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-0874e80b5349> in <module>()
#       5 print('generate...')
#       6 tic = time.time()
# ----> 7 generated = model.generate(start_data=start_tensor, num_generate=200)
#       8 #generated = model.fast_generate(40000, first_sample=0.1)
#       9 toc = time.time()
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/model.py in generate(self, num_generate, start_data)
#     101                                 s = Variable(torch.FloatTensor([s]))
#     102                                 s = (s / self.num_classes) * 2. - 1
# --> 103                         else:
#     104                                 max = torch.max(o, 0)[1].float()
#     105                                 s = (max / self.num_classes) * 2. - 1 # new sample
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/model.py in forward(self, input)
#      76
#      77         def generate(self, num_generate, start_data=torch.FloatTensor([0])):
# ---> 78 		"""
#      79                 :param start_data: torch tensor with length of at least one, used to start the generation process
#      80                 :param num_generate: number of samples that will be generated
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/container.py in forward(self, input)
#      62     def forward(self, input):
#      63         for module in self._modules.values():
# ---> 64             input = module(input)
#      65         return input
#      66
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/wavenet_modules.py in forward(self, x)
#      45
#      46         def forward(self, x):
# ---> 47                 x = dilate(x, self.dilation)
#      48
#      49                 l = x.size(2)
#
# KeyboardInterrupt:

# %%
fig = plt.figure()
plt.plot(generated.data[-200:].numpy())

# %%
print('generate...')
tic = time.time()
[generated, support_generated] = model.fast_generate(200, first_samples=start_tensor)
toc = time.time()
print('Generating took {} seconds.'.format(toc-tic))

fig = plt.figure()
plt.plot(support_generated)

# %%
torch.save(model.state_dict(), "trained_state_saber")
