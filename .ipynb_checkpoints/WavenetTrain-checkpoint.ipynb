# %% [markdown]
# # WaveNet Training

# %%
from model import WaveNetModel, Optimizer, WaveNetData

import torch
import numpy as np
import time

from IPython.display import Audio
from IPython.core.debugger import Tracer
from matplotlib import pyplot as plt
from matplotlib import pylab as pl
from IPython import display

# %matplotlib notebook

# %% [markdown]
# ## Setup Model

# %%
train_sample = "train_samples/saber.wav"
layers = 10
blocks = 2
classes = 128
hidden_channels = 32
kernel_size = 8

use_cuda = torch.cuda.is_available()

# %%
model = WaveNetModel(num_layers=layers,
                     num_blocks=blocks,
                     num_classes=classes,
                     hidden_channels=hidden_channels,
                     kernel_size=kernel_size)

if use_cuda:
    model.cuda()
    print("use cuda")

#print("model: ", model)
print("scope: ", model.scope)
print(model.parameter_count(), " parameters")

data = WaveNetData(train_sample,
                   input_length=model.scope,
                   target_length=model.last_block_scope,
                   num_classes=model.num_classes,
                   cuda=use_cuda)
# Out:
# scope:  14834
# 180608  paramaters

# %%
start_tensor = data.get_minibatch([model.scope])[0].squeeze()

plt.ion()
plt.plot(start_tensor[-200:].numpy())
plt.ioff()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Train Model

# %%
learning_rate = 0.001
mini_batch_size = 4
avg_length = 4
epochs = 100

# %%
optimizer = Optimizer(model,
                      learning_rate=learning_rate,
                      stop_threshold=0.1,
                      avg_length=avg_length,
                      mini_batch_size=mini_batch_size)

def hook(losses):
    ax.clear()
    ax.plot(losses)
    fig.canvas.draw()
    
optimizer.hook = hook

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

print('start training...')
tic = time.time()
optimizer.train(data, epochs=epochs)
toc = time.time()
print('Training took {} seconds.'.format(toc-tic))
# Out:
# <img src="data:image/png;base64,...">
# start training...
# epoch  0
# epoch  1
# epoch  2
# epoch  3
# epoch  4
# epoch  5
# epoch  6
# epoch  7
# epoch  8
# epoch  9
# epoch  10
# epoch  11
# epoch  12
# epoch  13
# epoch  14
# epoch  15
# epoch  16
# epoch  17
# epoch  18
# epoch  19
# epoch  20
# epoch  21
# epoch  22
# epoch  23
# epoch  24
# epoch  25
# epoch  26
# epoch  27
# epoch  28
# epoch  29
# epoch  30
# epoch  31
# epoch  32
# epoch  33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-71886b0f1a6a> in <module>()
#       8 print('start training...')
#       9 tic = time.time()
# ---> 10 optimizer.train(data, epochs=epochs)
#      11 toc = time.time()
#      12 print('Training took {} seconds.'.format(toc-tic))
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/model.py in train(self, data, epochs)
#     192                         inputs, targets = data.get_minibatch(minibatch_indices)
#     193
# --> 194                         output = self.model(Variable(inputs))
#     195
#     196                         targets = targets.view(targets.size(0)*targets.size(1))
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/model.py in forward(self, input)
#      58
#      59         def forward(self, input):
# ---> 60                 x = self.main(input)
#      61                 return x
#      62
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/container.py in forward(self, input)
#      62     def forward(self, input):
#      63         for module in self._modules.values():
# ---> 64             input = module(input)
#      65         return input
#      66
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/wavenet_modules.py in forward(self, input)
#      76                         r = constant_pad_1d(r, self.kernel_size - l, dimension=2, pad_start=True)
#      77
# ---> 78                 r = self.dil_conv(r)
#      79                 r = F.relu(r)
#      80                 r = self.onexone_conv(r)
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     141     def forward(self, input):
#     142         return F.conv1d(input, self.weight, self.bias, self.stride,
# --> 143                         self.padding, self.dilation, self.groups)
#     144
#     145
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/functional.py in conv1d(input, weight, bias, stride, padding, dilation, groups)
#      60     f = ConvNd(_single(stride), _single(padding), _single(dilation), False,
#      61                _single(0), groups, torch.backends.cudnn.benchmark, torch.backends.cudnn.enabled)
# ---> 62     return f(input, weight, bias)
#      63
#      64
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), "model_parameters/saber_10-2-128-32-8")
