# %%
import time

from model import Model, Optimizer, WavenetData

from IPython.display import Audio
from IPython.core.debugger import Tracer
from matplotlib import pyplot as plt
from matplotlib import pylab as pl
from IPython import display
import torch
import numpy as np
#%matplotlib inline
# %matplotlib notebook

# %%
model = Model(num_time_samples=10000, 
              num_blocks=2, 
              num_layers=11, 
              num_hidden=128, 
              num_classes=256, 
              sampled_generation=False)

model.load_state_dict(torch.load("trained_state_sapiens_11025"))

data = WavenetData('sapiens_11025.wav',
                   input_length=model.scope,
                   target_length=model.last_block_scope,
                   num_classes=model.num_classes)
# Out:
# current scope:  1
# current scope:  3
# current scope:  7
# current scope:  15
# current scope:  31
# current scope:  63
# current scope:  127
# current scope:  255
# current scope:  511
# current scope:  1023
# current scope:  2047
# current scope:  2048
# current scope:  2050
# current scope:  2054
# current scope:  2062
# current scope:  2078
# current scope:  2110
# current scope:  2174
# current scope:  2302
# current scope:  2558
# current scope:  3070
# current scope:  4094
# scope:  6142

# %%
start_tensor = data.get_minibatch([30000])[0].squeeze()
#start_tensor = torch.zeros((model.scope)) + 0.0

plt.ion()
plt.plot(start_tensor.numpy())
plt.ioff()
# Out:
# <img src="data:image/png;base64,...">

# %%
print('generate...')
tic = time.time()
generated = model.generate(start_data=start_tensor, num_generate=100)
toc = time.time()
print('Generating took {} seconds.'.format(toc-tic))

fig = plt.figure()
plt.plot(generated.data[-100:].numpy())
# Out:
# generate...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c13c5de6072c> in <module>()
#       1 print('generate...')
#       2 tic = time.time()
# ----> 3 generated = model.generate(start_data=start_tensor, num_generate=100)
#       4 toc = time.time()
#       5 print('Generating took {} seconds.'.format(toc-tic))
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/model.py in generate(self, num_generate, start_data)
#      97                 for i in range(num_generate):
#      98                         input = generated[-self.scope:].view(1, 1, -1)
# ---> 99                         o = self.forward(input)[-1, :].squeeze()
#     100
#     101                         if self.sampled_generation:
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/model.py in forward(self, input)
#      76                 #       gpu_ids = range(self.ngpu)
#      77                 # x = nn.parallel.data_parallel(self.main, input, gpu_ids)
# ---> 78                 x = self.main(input)
#      79                 return x
#      80
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/container.py in forward(self, input)
#      62     def forward(self, input):
#      63         for module in self._modules.values():
# ---> 64             input = module(input)
#      65         return input
#      66
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/wavenet_modules.py in forward(self, x)
#      52                         x = constant_pad_1d(x, self.kernel_size-l, dimension=2, pad_start=True)
#      53
# ---> 54                 r = self.conv(x)
#      55
#      56                 if self.residual:
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     141     def forward(self, input):
#     142         return F.conv1d(input, self.weight, self.bias, self.stride,
# --> 143                         self.padding, self.dilation, self.groups)
#     144
#     145
#
# /Users/vincentherrmann/anaconda3/lib/python3.5/site-packages/torch/nn/functional.py in conv1d(input, weight, bias, stride, padding, dilation, groups)
#      60     f = ConvNd(_single(stride), _single(padding), _single(dilation), False,
#      61                _single(0), groups, torch.backends.cudnn.benchmark, torch.backends.cudnn.enabled)
# ---> 62     return f(input, weight, bias)
#      63
#      64
#
# KeyboardInterrupt:

# %%
print('generate...')
tic = time.time()
model.sample_generation = False
#[fast_generated, support_generated] = model.fast_generate(600, first_samples=torch.zeros((1)))
[fast_generated, support_generated] = model.fast_generate(600, first_samples=start_tensor)
toc = time.time()
print('Generating took {} seconds.'.format(toc-tic))

fig = plt.figure()
plt.plot(fast_generated)
# Out:
# generate...
# Generating took 34.93300414085388 seconds.
# <img src="data:image/png;base64,...">

# %%
sample_length = 22050

tic = time.time()
#[generated_sample, support_generated] = model.fast_generate(sample_length, first_samples=torch.zeros((1)))
[generated_sample, support_generated] = model.fast_generate(sample_length, first_samples=start_tensor)
toc = time.time()
print('Generating took {} seconds.'.format(toc-tic))
# Out:
# Generating took 74.4179859161377 seconds.

# %%
np_sample = np.asarray(generated_sample)
print("sample: ", np_sample)

from scipy.io import wavfile
wavfile.write('generated_sapiens_11025_sample.wav', 11025, np_sample)
# Out:
# sample:  [-0.2265625 -0.1796875 -0.1015625 ..., -0.0078125 -0.0078125 -0.0078125]

# %%
fig = plt.figure()
plt.plot(generated_sample[0:1000])

from IPython.display import Audio
Audio(generated_sample, rate=11025)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
