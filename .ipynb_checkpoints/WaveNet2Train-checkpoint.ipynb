# %% [markdown]
# # Train WaveNet

# %%
from wavenet_model import WaveNetModel
from wavenet_training import AudioFileLoader, WaveNetOptimizer

import torch
import numpy as np
import time

from IPython.display import Audio
from matplotlib import pyplot as plt
from matplotlib import pylab as pl
from IPython import display

# %matplotlib notebook

# %% [markdown]
# ## Setup Model

# %%
train_samples = ["train_samples/violin.wav"]
sampling_rate = 44100
init_model = None

layers = 7
blocks = 2
classes = 128
dilation_channels = 64
residual_channels = 64
skip_channels = 64
kernel_size = 2
dtype = torch.FloatTensor
ltype = torch.LongTensor

use_cuda = torch.cuda.is_available()
if use_cuda:
    dtype = torch.cuda.FloatTensor
    ltype = torch.cuda.LongTensor

# %%
model = WaveNetModel(layers=layers,
                     blocks=blocks,
                     dilation_channels=dilation_channels,
                     residual_channels=residual_channels,
                     skip_channels=skip_channels,
                     classes=classes,
                     kernel_size=kernel_size,
                     dtype=dtype)

if use_cuda:
    model.cuda()
    print("use cuda")

#print("model: ", model)
print("receptive_field: ", model.receptive_field)
print("parameter count: ", model.parameter_count())

if init_model != None:
    if use_cuda:
        model.load_state_dict(torch.load(init_model))
    else:
        # move to cpu
        model.load_state_dict(torch.load(init_model, map_location=lambda storage, loc: storage))

data_loader = AudioFileLoader(train_samples,
                              classes=classes,
                              receptive_field=model.receptive_field,
                              target_length=model.output_length,
                              dtype=dtype,
                              ltype=ltype,
                              sampling_rate=sampling_rate)
# Out:
# receptive_field:  318
# parameter count:  352448
# total duration of training data:  0.6  s

# %%
data_loader.start_new_epoch()
start_data = data_loader.get_wavenet_minibatch([model.receptive_field], 
                                               model.receptive_field,
                                               model.output_length)[0]
start_data = start_data.squeeze()

plt.ion()
plt.plot(start_data[-200:].numpy())
plt.ioff()
# Out:
# There are not enough segments available in the training set to produce one chunk
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-b1211530370a> in <module>()
#       1 data_loader.start_new_epoch()
# ----> 2 start_data = data_loader.get_wavenet_minibatch([model.receptive_field],
#       3                                                model.receptive_field,
#       4                                                model.output_length)[0]
#       5 start_data = start_data.squeeze()
#
# AttributeError: 'AudioFileLoader' object has no attribute 'get_wavenet_minibatch'

# %% [markdown]
# ## Train Model

# %%
learning_rate = 0.001
mini_batch_size = 4
report_interval = 4
test_interval = 16
snapshot_interval = 256
epochs = 200
segments_per_chunk=8
examples_per_segment=8
test_segments = 8
examples_per_test_segment = 4
model_path = "model_parameters/violin_7-2-128-64-64-64-2"

# %%
def report_callback(opt):
    ax.clear()
    ax.plot(opt.loss_positions, opt.losses)
    ax.plot(opt.test_result_positions, opt.test_results)
    fig.canvas.draw()
    
def test_callback(test_results, positions):
    
optimizer = WaveNetOptimizer(model,
                             data=data_loader,
                             test_segments=test_segments,
                             examples_per_test_segment=examples_per_test_segment,
                             report_callback=report_callback,
                             report_interval=report_interval,
                             test_interval=test_interval,
                             test_report_callback=test_callback,
                             snapshot_interval=snapshot_interval,
                             snapshot_file=model_path)
# Out:
# The test set has a total duration of  0.046439909297052155  s

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

print('start training...')
tic = time.time()
optimizer.train(learning_rate=learning_rate,
                minibatch_size=mini_batch_size,
                epochs=epochs,
                segments_per_chunk=segments_per_chunk,
                examples_per_segment=examples_per_segment)
toc = time.time()
print('Training took {} seconds.'.format(toc-tic))
# Out:
# <img src="data:image/png;base64,...">
# start training...
# epoch  0
# load new chunk with start segment index  0
# loading this chunk took  0.006531953811645508  seconds
# use loaded chunk with  8 segments
# load new chunk with start segment index  11
# loading this chunk took  0
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  6
# loading this chunk took  0.011198043823242188  seconds
# test loss:  2.2107605934143066
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  15
# loading this chunk took  0.010357856750488281  seconds
# test loss:  2.2535845041275024
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  24
# loading this chunk took  0.00970602035522461  seconds
# test loss:  2.2273061275482178
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  35
# loading this chunk took  0.010632038116455078  seconds
# test loss:  2.258839249610901
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  44
# epoch  29
# loading this chunk took  0.009122133255004883  seconds
# test loss:  2.304345488548279
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  6
# loading this chunk took  0.01059103012084961  seconds
# test loss:  2.2771897315979004
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  17
# loading this chunk took  0.009554862976074219  seconds
# test loss:  2.2296561002731323
# 2017-05-18 12:20:19.903304 : snapshot saved to  model_parameters/violin_7-2-128-64-64-64-2
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  27
# loading this chunk took  0.01234889030456543  seconds
# test loss:  2.2992587089538574
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  38
# loading this chunk took  0.009798049926757812  seconds
# test loss:  2.306520462036133
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  46
# epoch  30
# loading this chunk took  0.010016918182373047  seconds
# test loss:  2.3825571537017822
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  6
# loading this chunk took  0.010217905044555664  seconds
# test loss:  2.4274266958236694
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  15
# loading this chunk took  0.009792089462280273  seconds
# test loss:  2.39939546585083
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  23
# loading this chunk took  0.009737968444824219  seconds
# test loss:  2.4276247024536133
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  34
# loading this chunk took  0.009845972061157227  seconds
# test loss:  2.39826500415802
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  43
# epoch  31
# loading this chunk took  0.010752201080322266  seconds
# test loss:  2.438306450843811
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  3
# loading this chunk took  0.011951923370361328  seconds
# test loss:  2.2961963415145874
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  13
# loading this chunk took  0.008561849594116211  seconds
# test loss:  2.28157114982605
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  21
# loading this chunk took  0.010920047760009766  seconds
# test loss:  2.297497034072876
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  32
# loading this chunk took  0.010264873504638672  seconds
# test loss:  2.418415904045105
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  45
# epoch  32
# loading this chunk took  0.009571075439453125  seconds
# test loss:  2.406515955924988
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  6
# loading this chunk took  0.009804964065551758  seconds
# test loss:  2.317196249961853
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  14
# loading this chunk took  0.010835886001586914  seconds
# test loss:  2.3085222244262695
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  25
# loading this chunk took  0.009217977523803711  seconds
# test loss:  2.292640209197998
# 2017-05-18 12:21:36.138334 : snapshot saved to  model_parameters/violin_7-2-128-64-64-64-2
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  37
# loading this chunk took  0.010309934616088867  seconds
# test loss:  2.29343581199646
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  48
# epoch  33
# loading this chunk took  0.01129603385925293  seconds
# test loss:  2.4473730325698853
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  8
# loading this chunk took  0.01009988784790039  seconds
# test loss:  2.4405792951583862
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  16
# loading this chunk took  0.009642839431762695  seconds
# test loss:  2.444252371788025
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  25
# loading this chunk took  0.009879827499389648  seconds
# test loss:  2.2455554008483887
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  35
# loading this chunk took  0.010944843292236328  seconds
# test loss:  2.2414928674697876
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  47
# epoch  34
# loading this chunk took  0.009378194808959961  seconds
# test loss:  2.2489871978759766
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  7
# loading this chunk took  0.01063990592956543  seconds
# test loss:  2.3544918298721313
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  20
# loading this chunk took  0.010653018951416016  seconds
# test loss:  2.244393229484558
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  28
# loading this chunk took  0.009055852890014648  seconds
# test loss:  2.281335949897766
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  37
# loading this chunk took  0.010812997817993164  seconds
# test loss:  2.3368438482284546
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  46
# epoch  35
# loading this chunk took  0.01022791862487793  seconds
# test loss:  2.658639669418335
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  6
# loading this chunk took  0.01141214370727539  seconds
# test loss:  2.5709903240203857
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  17
# loading this chunk took  0.010074138641357422  seconds
# test loss:  2.2264801263809204
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  25
# loading this chunk took  0.009450912475585938  seconds
# test loss:  2.353069543838501
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  33
# loading this chunk took  0.010255813598632812  seconds
# test loss:  2.3093291521072388
# 2017-05-18 12:22:52.455580 : snapshot saved to  model_parameters/violin_7-2-128-64-64-64-2
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  44
# epoch  36
# loading this chunk took  0.009397029876708984  seconds
# test loss:  2.2788482904434204
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  5
# loading this chunk took  0.010197877883911133  seconds
# test loss:  2.266943573951721
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  19
# loading this chunk took  0.01115107536315918  seconds
# test loss:  2.268723726272583
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  28
# loading this chunk took  0.009245157241821289  seconds
# test loss:  2.2298184633255005
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  37
# loading this chunk took  0.010158061981201172  seconds
# test loss:  2.295137882232666
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  46
# epoch  37
# loading this chunk took  0.009461164474487305  seconds
# test loss:  2.2633447647094727
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  7
# loading this chunk took  0
: snapshot saved to  model_parameters/violin_7-2-128-64-64-64-2
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  31
# loading this chunk took  0.010073184967041016  seconds
# test loss:  2.422154188156128
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  42
# epoch  46
# loading this chunk took  0.00993490219116211  seconds
# test loss:  2.333818793296814
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  1
# loading this chunk took  0.010026931762695312  seconds
# test loss:  2.2978363037109375
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  12
# loading this chunk took  0.009695053100585938  seconds
# test loss:  2.4048629999160767
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  23
# loading this chunk took  0.011058807373046875  seconds
# test loss:  2.3362256288528442
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  34
# loading this chunk took  0.010116100311279297  seconds
# test loss:  2.343145728111267
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  43
# epoch  47
# loading this chunk took  0.010168075561523438  seconds
# test loss:  2.2893192768096924
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  4
# loading this chunk took  0.010128974914550781  seconds
# test loss:  2.3854395151138306
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  15
# loading this chunk took  0.00892019271850586  seconds
# test loss:  2.350710868835449
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  26
# loading this chunk took  0.010233163833618164  seconds
# test loss:  2.379083275794983
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  36
# loading this chunk took  0.011976003646850586  seconds
# test loss:  2.355364441871643
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  45
# epoch  48
# loading this chunk took  0.010712862014770508  seconds
# test loss:  2.3372994661331177
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  7
# loading this chunk took  0.010203838348388672  seconds
# test loss:  2.3633885383605957
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  15
# loading this chunk took  0.01013493537902832  seconds
# test loss:  2.372681736946106
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  25
# loading this chunk took  0.010387897491455078  seconds
# test loss:  2.391449451446533
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  34
# loading this chunk took  0.009788036346435547  seconds
# test loss:  2.4861241579055786
# 2017-05-18 12:27:59.449260 : snapshot saved to  model_parameters/violin_7-2-128-64-64-64-2
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  44
# epoch  49
# loading this chunk took  0.010022163391113281  seconds
# test loss:  2.410632848739624
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  5
# loading this chunk took  0.01021885871887207  seconds
# test loss:  2.4872701168060303
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  16
# loading this chunk took  0.009957075119018555  seconds
# test loss:  2.3833028078079224
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  24
# loading this chunk took  0.010396003723144531  seconds
# test loss:  2.42690646648407
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  32
# loading this chunk took  0.009409189224243164  seconds
# test loss:  2.577967047691345
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  45
# epoch  50
# loading this chunk took  0.011030912399291992  seconds
# test loss:  2.4300163984298706
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  4
# loading this chunk took  0.008440971374511719  seconds
# test loss:  2.4845179319381714
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  13
# loading this chunk took  0.01030588150024414  seconds
# test loss:  2.421958327293396
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  23
# loading this chunk took  0.011040925979614258  seconds
# test loss:  2.293118476867676
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  35
# loading this chunk took  0.010120868682861328  seconds
# test loss:  2.247348427772522
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  44
# epoch  51
# loading this chunk took  0.010696172714233398  seconds
# test loss:  2.3216912746429443
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  4
# loading this chunk took  0.009492874145507812  seconds
# test loss:  2.2672924995422363
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  14
# loading this chunk took  0.010121822357177734  seconds
# test loss:  2.196220874786377
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  23
# loading this chunk took  0.010323047637939453  seconds
# test loss:  2.194605827331543
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  32
# loading this chunk took  0.009953022003173828  seconds
# test loss:  2.24360728263855
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  41
# epoch  52
# loading this chunk took  0.009943008422851562  seconds
# test loss:  2.260092854499817
# 2017-05-18 12:29:15.973075 : snapshot saved to  model_parameters/violin_7-2-128-64-64-64-2
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  1
# loading this chunk took  0.010263919830322266  seconds
# test loss:  2.380557656288147
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  12
# loading this chunk took  0.009118080139160156  seconds
# test loss:  2.3258705139160156
# use new chunk
# use loaded chunk with  8 segments
# ...
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  34
# loading this chunk took  0.012078046798706055  seconds
# test loss:  2.693769097328186
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  44
# epoch  186
# loading this chunk took  0.009836196899414062  seconds
# test loss:  2.9992921352386475
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  2
# loading this chunk took  0.01065206527709961  seconds
# test loss:  3.115653872489929
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  13
# loading this chunk took  0.011120080947875977  seconds
# test loss:  3.0168360471725464
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  24
# loading this chunk took  0.00982809066772461  seconds
# test loss:  2.9103970527648926
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  33
# loading this chunk took  0.010579109191894531  seconds
# test loss:  2.947718381881714
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  46
# epoch  187
# loading this chunk took  0.009743928909301758  seconds
# test loss:  2.9665441513061523
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  6
# loading this chunk took  0.011381149291992188  seconds
# test loss:  3.2138986587524414
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  15
# loading this chunk took  0.010994195938110352  seconds
# test loss:  3.3252464532852173
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  23
# loading this chunk took  0.011359930038452148  seconds
# test loss:  3.107017755508423
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  33
# loading this chunk took  0.009635210037231445  seconds
# test loss:  3.15286386013031
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  43
# epoch  188
# loading this chunk took  0.010753154754638672  seconds
# test loss:  3.1700665950775146
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  6
# loading this chunk took  0.009763956069946289  seconds
# test loss:  2.9792346954345703
# 2017-05-18 13:24:09.062539 : snapshot saved to  model_parameters/violin_7-2-128-64-64-64-2
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  15
# loading this chunk took  0.010145902633666992  seconds
# test loss:  3.130752682685852
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  24
# loading this chunk took  0.009736061096191406  seconds
# test loss:  3.0695009231567383
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  32
# loading this chunk took  0.01092219352722168  seconds
# test loss:  3.005429744720459
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  45
# epoch  189
# loading this chunk took  0.011101961135864258  seconds
# test loss:  3.1138817071914673
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  5
# loading this chunk took  0.00998687744140625  seconds
# test loss:  3.12797474861145
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  14
# loading this chunk took  0.011217117309570312  seconds
# test loss:  2.908185362815857
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  24
# loading this chunk took  0.010361909866333008  seconds
# test loss:  2.985332489013672
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  32
# loading this chunk took  0.00952005386352539  seconds
# test loss:  2.9395467042922974
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  45
# epoch  190
# loading this chunk took  0.009796142578125  seconds
# test loss:  2.866745948791504
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  4
# loading this chunk took  0.009625911712646484  seconds
# test loss:  2.8225210905075073
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  13
# loading this chunk took  0.009096860885620117  seconds
# test loss:  2.856849431991577
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  23
# loading this chunk took  0.012156009674072266  seconds
# test loss:  2.9016422033309937
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  33
# loading this chunk took  0.010911941528320312  seconds
# test loss:  2.694622278213501
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  45
# epoch  191
# loading this chunk took  0.01061701774597168  seconds
# test loss:  2.771544098854065
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  5
# loading this chunk took  0.00992584228515625  seconds
# test loss:  2.750231385231018
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  17
# loading this chunk took  0.009741067886352539  seconds
# test loss:  2.6721028089523315
# 2017-05-18 13:25:29.501584 : snapshot saved to  model_parameters/violin_7-2-128-64-64-64-2
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  25
# loading this chunk took  0.010954141616821289  seconds
# test loss:  2.7775989770889282
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  33
# loading this chunk took  0.009834051132202148  seconds
# test loss:  2.7815520763397217
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  43
# epoch  192
# loading this chunk took  0.011838912963867188  seconds
# test loss:  2.7188100814819336
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  3
# loading this chunk took  0.010734081268310547  seconds
# test loss:  2.6848453283309937
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  13
# loading this chunk took  0.008891820907592773  seconds
# test loss:  2.6987260580062866
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  24
# loading this chunk took  0.012406110763549805  seconds
# test loss:  2.620524287223816
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  34
# loading this chunk took  0.011265993118286133  seconds
# test loss:  2.6594762802124023
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  44
# epoch  193
# loading this chunk took  0.010144948959350586  seconds
# test loss:  2.6374127864837646
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  5
# loading this chunk took  0.010269880294799805  seconds
# test loss:  2.6629608869552612
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  16
# loading this chunk took  0.011182069778442383  seconds
# test loss:  2.616175651550293
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  24
# loading this chunk took  0.01043701171875  seconds
# test loss:  2.6927571296691895
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  33
# loading this chunk took  0.011428117752075195  seconds
# test loss:  2.56705379486084
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  48
# epoch  194
# loading this chunk took  0.011240959167480469  seconds
# test loss:  2.5768829584121704
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  7
# loading this chunk took  0.011160135269165039  seconds
# test loss:  2.5393913984298706
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  18
# loading this chunk took  0.011519193649291992  seconds
# test loss:  2.65527880191803
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  29
# loading this chunk took  0.008785009384155273  seconds
# test loss:  2.6125510931015015
# 2017-05-18 13:26:50.443150 : snapshot saved to  model_parameters/violin_7-2-128-64-64-64-2
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  40
# loading this chunk took  0.010113954544067383  seconds
# test loss:  2.575485110282898
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  50
# epoch  195
# loading this chunk took  0.010548114776611328  seconds
# test loss:  2.606820583343506
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  10
# loading this chunk took  0.010637998580932617  seconds
# test loss:  2.5946083068847656
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  21
# loading this chunk took  0.010241031646728516  seconds
# test loss:  2.64284348487854
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  31
# loading this chunk took  0.010536909103393555  seconds
# test loss:  2.556192398071289
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  42
# epoch  196
# loading this chunk took  0.011923074722290039  seconds
# test loss:  2.5133376121520996
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  2
# loading this chunk took  0.010350942611694336  seconds
# test loss:  2.50097119808197
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  14
# loading this chunk took  0.01122903823852539  seconds
# test loss:  2.5747181177139282
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  22
# loading this chunk took  0.009723901748657227  seconds
# test loss:  2.4938607215881348
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  31
# loading this chunk took  0.010159969329833984  seconds
# test loss:  2.516193151473999
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  43
# epoch  197
# loading this chunk took  0.010280132293701172  seconds
# test loss:  2.5000487565994263
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  4
# loading this chunk took  0.009455204010009766  seconds
# test loss:  2.509681224822998
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  15
# loading this chunk took  0.010106086730957031  seconds
# test loss:  2.477527618408203
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  25
# loading this chunk took  0.010298013687133789  seconds
# test loss:  2.5593026876449585
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  37
# loading this chunk took  0.01137995719909668  seconds
# test loss:  2.625023365020752
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  46
# epoch  198
# loading this chunk took  0.011599063873291016  seconds
# test loss:  2.580617308616638
# 2017-05-18 13:28:11.512131 : snapshot saved to  model_parameters/violin_7-2-128-64-64-64-2
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  7
# loading this chunk took  0.010601997375488281  seconds
# test loss:  2.610805034637451
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  16
# loading this chunk took  0.009384870529174805  seconds
# test loss:  2.5443968772888184
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  25
# loading this chunk took  0.011178970336914062  seconds
# test loss:  2.5644770860671997
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  35
# loading this chunk took  0.010920047760009766  seconds
# test loss:  2.605412006378174
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  45
# epoch  199
# loading this chunk took  0.010493040084838867  seconds
# test loss:  2.5882928371429443
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  9
# loading this chunk took  0.010081052780151367  seconds
# test loss:  2.50314462184906
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  18
# loading this chunk took  0.010661125183105469  seconds
# test loss:  2.5000247955322266
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  28
# loading this chunk took  0.00987386703491211  seconds
# test loss:  2.532028555870056
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  37
# loading this chunk took  0.011088132858276367  seconds
# test loss:  2.498578190803528
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  49
# training finished
# training finished
# training finished
# training finished
# training finished
# training finished
# training finished
# loading this chunk took  0.010512113571166992  seconds
# test loss:  2.5441884994506836
# use new chunk
# use loaded chunk with  8 segments
# load new chunk with start segment index  50
# training finished
# Exception in thread Thread-1417:
# Traceback (most recent call last):
#   File "/Users/vincentherrmann/anaconda3/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/Users/vincentherrmann/anaconda3/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/wavenet_training.py", line 320, in load_new_chunk
#     segment_position = self.segment_positions[current_chunk_position]
# IndexError: index 50 is out of bounds for axis 0 with size 50
# test loss:  2.4873372316360474
# use new chunk
# use loaded chunk with  0 segments
# no data loaded?!
# load new chunk with start segment index  50
# training finished
# Exception in thread Thread-1418:
# Traceback (most recent call last):
#   File "/Users/vincentherrmann/anaconda3/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/Users/vincentherrmann/anaconda3/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/wavenet_training.py", line 320, in load_new_chunk
#     segment_position = self.segment_positions[current_chunk_position]
# IndexError: index 50 is out of bounds for axis 0 with size 50
# test loss:  2.4866827726364136
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-1fb5df6ca437> in <module>()
#      12                 epochs=epochs,
#      13                 segments_per_chunk=segments_per_chunk,
# ---> 14                 examples_per_segment=examples_per_segment)
#      15 toc = time.time()
#      16 print('Training took {} seconds.'.format(toc-tic))
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/wavenet_training.py in train(self, learning_rate, minibatch_size, epochs, segments_per_chunk, examples_per_segment)
#     131
#     132             # get data
# --> 133             inputs, targets = self.data.get_minibatch(minibatch_size)
#     134             targets = targets.view(targets.size(0) * targets.size(1))
#     135             inputs = Variable(inputs)
#
# /Users/vincentherrmann/Documents/Software/PyTorch/WaveNet/wavenet_training.py in get_minibatch(self, minibatch_size)
#     391             position = (index % self.examples_per_segment) * self.target_length + self.receptive_field
#     392
# --> 393             if position > self.inputs[segment].size(0):
#     394                 print("index ", position, " is not avialable in a tensor of size ", self.inputs[segment].size(0))
#     395
#
# IndexError: list index out of range

# %%
torch.save(model.state_dict(), model_path)
